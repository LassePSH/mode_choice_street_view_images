# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('/home/lpsha/s154446/design_standard_public_transport/paper_1/trajectory_for_mode_choice/src/trajectory_features_foot.csv')

# %%
df.columns = df.columns.str.replace(r'^home_', 'h2st_', regex=True)
df.columns = df.columns.str.replace(r'^act_', 'a2st_', regex=True)

# %%
df.drop(columns=['mode'], inplace=True)

# %%
df.to_csv('/home/lpsha/s154446/design_standard_public_transport/paper_1/trajectory_for_mode_choice/src/trajectory_features_full.csv', index=False)

# %%
df.columns
# Out:
# Index(['h2st_NaN_density_mean', 'h2st_NaN_density_median',
#        'h2st_NaN_density_std', 'h2st_NaN_density_min', 'h2st_NaN_density_max',
#        'h2st_sidewalk_density_mean', 'h2st_sidewalk_density_median',
#        'h2st_sidewalk_density_std', 'h2st_sidewalk_density_min',
#        'h2st_sidewalk_density_max',
#        ...
#        'h2a_car_vehicle_life_g2_density_quantile_std',
#        'h2a_car_vehicle_life_g2_density_quantile_min',
#        'h2a_car_vehicle_life_g2_density_quantile_max', 'h2a_car_n_images',
#        'h2a_car_distance_m', 'h2a_car_duration_s', 'SessionId', 'TurId',
#        'HOME_NearestStation', 'ACT_NearestStation'],
#       dtype='object', length=3419)
